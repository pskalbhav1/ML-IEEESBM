# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import random

# %% [markdown]
# ## 1]

# %%
a=np. array([1023,5202,6230,1671,1682,5241,4532])
np.argsort(a)
# Out:
# array([0, 3, 4, 6, 1, 5, 2], dtype=int64)

# %% [markdown]
# ## 2]

# %%
a=np.array([('James', 5, 48.5 ), ('Nail', 6, 52.5 ), ('Paul', 5, 42.1 ), ('Pit', 5, 40.11)],
           dtype=[('name', (np.str_, 10)), ('class', np.int32), ('height', np.float64)])
b = np.sort(a, order='class') 
c = np.sort(b, order='height') 
c
# Out:
# array([('Pit', 5, 40.11), ('Paul', 5, 42.1 ), ('James', 5, 48.5 ),
#        ('Nail', 6, 52.5 )],
#       dtype=[('name', '<U10'), ('class', '<i4'), ('height', '<f8')])

# %% [markdown]
# ## 3]

# %%
np.random.randn(3,3,3)
# Out:
# array([[[ 0.03591306, -0.59782453, -0.53275636],
#         [ 0.55256421, -0.11262131, -1.46231633],
#         [-1.86416535, -0.34463586,  0.45703175]],
#
#        [[-0.47982272, -0.99099655,  0.14460447],
#         [-0.25156211,  0.86666001, -0.17118297],
#         [ 0.24895473, -0.36589839, -2.23735714]],
#
#        [[-1.81948537,  0.64960335, -0.56426718],
#         [-1.40408395,  1.01490811, -1.07364928],
#         [ 0.09440138, -1.14000429,  0.53848531]]])

# %% [markdown]
# ## 4]

# %%
x=np.linspace(-1,1,100)
p=0.5
y=p*x
plt.plot(x,y)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Straight Line Plot")
# Out:
# Text(0.5, 1.0, 'Straight Line Plot')

# %% [markdown]
# ## 5]

# %%
x=np.linspace(10,30,100)
y1=[((-3)*i + 70) for i in x if i<=20]
y2=[((2*i)-30) for i in x if i>20]
y3=[(2*i) for i in x if i<=20]
y4=[((-3*i)+100) for i in x if i>20]

y5=y1+y2
y6=y3+y4
plt.plot(x,y5,'.',color='b',label='line1-dotted')
plt.plot(x,y6,'--', color='r',label='line2-dashed')

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.legend()
plt.title("Plot with two or more lines with different styles")
plt.show()

# %% [markdown]
# ## 6]

# %%
arr=np.random.randn(5,5)
df=pd.DataFrame(arr, columns=['Hello', 'These','Are','Column','Names'],index=['Hello', 'These','Are','Row','Names'])
df
# Out:
#           Hello     These       Are    Column     Names
# Hello  0.982416  1.387101 -0.492281  1.307295 -0.396992
# These  0.277831 -1.451041  0.008981  0.041568 -0.388765
# Are    0.321631 -1.073525  0.238499  0.975840 -0.977559
# Row   -1.336242 -0.321987 -0.078325 -0.494805  0.671810
# Names -0.002509 -2.467337 -0.721298  0.419455  0.195208

# %% [markdown]
# ## 7]

# %%
balls = 25
x = [random.triangular() for i in range(balls)]
y = [random.gauss(0.5, 0.25) for i in range(balls)]
colors = [random.randint(1, 10) for i in range(balls)]
areas = [math.pi * random.randint(5, 15)**2 for i in range(balls)]
# draw the plot
plt.figure()
plt.scatter(x, y, s=areas, c=colors, alpha=0.85)
plt.axis([0.0, 1.0, 0.0, 1.0])
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
